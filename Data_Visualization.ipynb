# %% [markdown]
# <a href="https://colab.research.google.com/github/NishmithaJR/Data-Analytics/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA VISUALIZATION

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import data
data=sns.load_dataset('titanic')

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#simple line plot
plt.plot(data['age'],data['fare'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Customizing graph
plt.plot(data['age'],data['fare'],color="red")
plt.xlabel("Age of Passengers")
plt.ylabel("Fare")
plt.title("Age-Fare")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Scatter plot
plt.plot(data['age'],data['fare'],"o")
plt.xlabel("Age of Passengers")
plt.ylabel("Fare")
plt.title("Age-Fare")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Same graph as above
plt.scatter(data['age'],data['fare'],c='red')
plt.xlabel("Age of Passengers")
plt.ylabel("Fare")
plt.title("Age-Fare")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#grouping data by different colors
color=[]
for sex in data['sex']:
  if sex == 'male':
    color.append('blue')
  else:
    color.append('red')
plt.scatter(data['age'],data['fare'],c=color)
plt.xlabel("Age of Passengers")
plt.ylabel("Fare")
plt.title("Age-Fare")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Another way of writing the above code
colors=['blue' if sex=='male' else 'red' for sex in data]
plt.scatter(data['age'],data['fare'],c=color)
plt.xlabel("Age of Passengers")
plt.ylabel("Fare")
plt.title("Age-Fare")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Histogram
plt.hist(data['survived'])
plt.show()

# %%
#Histogram
plt.hist(data['age'])
plt.show()

# %%
#Bins in Histogram
plt.hist(data['age'], bins=15) #bin makes the bars thinner
plt.show()

# %%
#Value Count
data.value_counts()
# Out:
# survived  pclass  sex     age   sibsp  parch  fare      embarked  class  who    adult_male  deck  embark_town  alive  alone
# 1         1       female  24.0  0      0      69.3000   C         First  woman  False       B     Cherbourg    yes    True     2
#                           58.0  0      0      26.5500   S         First  woman  False       C     Southampton  yes    True     1
#                           49.0  0      0      25.9292   S         First  woman  False       D     Southampton  yes    True     1
#                                 1      0      76.7292   C         First  woman  False       D     Cherbourg    yes    False    1
#                           50.0  0      1      247.5208  C         First  woman  False       B     Cherbourg    yes    False    1
#                                                                                                                               ..
#                           16.0  0      0      86.5000   S         First  woman  False       B     Southampton  yes    True     1
#                                        1      39.4000   S         First  woman  False       D     Southampton  yes    False    1
#                                               57.9792   C         First  woman  False       B     Cherbourg    yes    False    1
#                           17.0  1      0      57.0000   S         First  woman  False       B     Southampton  yes    False    1
#           3       male    32.0  0      0      8.0500    S         Third  man    True        E     Southampton  yes    True     1
# Name: count, Length: 181, dtype: int64

# %%
#value count for specific columns
data['age'].value_counts()
# Out:
# age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data['age'].value_counts().plot(kind='bar')
#this graph is so skewed as we have many ages
# Out:
# <Axes: xlabel='age'>

# %%
data['survived'].value_counts().plot(kind='bar')
#bar graph for survived is not skewed as we have only 1 and 0 in survived column
# Out:
# <Axes: xlabel='survived'>

# %%
#Count plot by seaborn library
sns.countplot(data=data)
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['age'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['survived'])
# Out:
# <Axes: ylabel='count'>

# %%
#Data representation more accurately
sns.countplot(data['survived'],hue=data['sex'])

# %%
#Division on basis of Pclass
sns.countplot(data=data,x='survived',hue='pclass')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
#scatter plot between survived & age with hue pclass
sns.scatterplot(data=data,x='survived',y='age',hue='pclass')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
#barplot between age & fare
sns.barplot(data=data,x='age',y='fare',hue='embarked')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
#barplot between sex & fare
sns.barplot(data=data,x='sex',y='fare',hue='embarked')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#barplot between sex & fare
sns.barplot(data=data,x='sex',y='fare',hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#pairplot of all
sns.pairplot(data=data,vars=['age','survived','sex','fare'])

# %%
#histograms of all
data.hist()
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
#boxplot of fare & sex(male, female)
sns.boxplot(data=data,x='sex',y='fare',hue='pclass')
#data outside is called outlier
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#boxenplot
sns.boxenplot(data=data,x='sex',y='fare',hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#Swarmplot
sns.swarmplot(data=data,x='sex',y='fare',hue='pclass')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 56.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 28.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='fare'>
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 65.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 42.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Stripplot
sns.stripplot(data=data,x='sex',y='fare',hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#heatmap
corr=data.corr()
sns.heatmap(corr)
#range of heatmap (-1 - +1)

# %%
#boxplot
sns.boxplot(data=data,x='sex',y='fare',hue='who')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#swarmplot
sns.swarmplot(data=data,x='sex',y='fare',hue='who')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 56.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 28.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='fare'>
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 65.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 42.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#boxenplot
sns.boxenplot(data=data,x='sex',y='fare',hue='who')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#stripplot
sns.stripplot(data=data,x='sex',y='fare',hue='who')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
 #violinplot
sns.violinplot(data=data,x='sex',y='fare',hue='who')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#lmplot
sns.lmplot(data=data,x='age',y='fare',hue='who')

# %%
#without hue
sns.lmplot(data=data,x='age',y='fare')

# %% [markdown]
# if we have to find a graph of age below 30

# %%
#boxplot
sns.boxplot(data=data[data['age']<30],x='age',y='fare',hue='who')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
 #Age_grwoth column is added in the last
data["age_growth"]=data['age']+10
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_growth
# 0    man        True  NaN  Southampton    no  False        32.0
# 1  woman       False    C    Cherbourg   yes  False        48.0
# 2  woman       False  NaN  Southampton   yes   True        36.0
# 3  woman       False    C  Southampton   yes  False        45.0
# 4    man        True  NaN  Southampton    no   True        45.0

# %%
#scatterplot
sns.scatterplot(data=data,x='age',y='age_growth',hue='who')
# Out:
# <Axes: xlabel='age', ylabel='age_growth'>

# %%
#new column of age_label
data['age_label']=pd.cut(data['age'],[0,10,18,30,40,80],labels=['kids','child','young'])
data.head()

# %%
#boxenplot
sns.boxenplot(data=data,x='fare',y='age_growth',hue='age_label')

# %%
 #boxenplot
sns.boxenplot(data=data,y='age_growth',x='sex',hue='age_label')
